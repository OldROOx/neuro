# %%
import pandas as pd

df = pd.read_csv('reporte_red_neuronal.csv')
df
# Out:
#    Peso_Inicial_W0  Peso_Inicial_W1  Peso_Inicial_W2  Peso_Final_W0  \
# 0         0.273857        -0.242956         0.502048      -0.026143
#
#    Peso_Final_W1  Peso_Final_W2  Error_Final_Magnitud
# 0       0.057044       0.502048                   0.0
